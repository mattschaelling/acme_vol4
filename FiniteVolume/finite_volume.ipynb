# %%
import numpy as np
from matplotlib import pyplot as plt
from math import floor

# %%
def upwind(u0, a, xmin, xmax, t_final, nt):
    """ Solve the advection equation with periodic
    boundary conditions on the interval [xmin, xmax]
    using the upwind finite volume scheme.
    Use u0 as the initial conditions.
    a is the constant from the PDE.
    Use the size of u0 as the number of nodes in
    the spatial dimension.
    Let nt be the number of spaces in the time dimension
    (this is the same as the number of steps if you do
    not include the initial state).
    Plot and show the computed solution along
    with the exact solution. """
    dt = float(t_final) / nt
    # Since we are doing periodic boundary conditions,
    # we need to divide by u0.size instead of (u0.size - 1).
    dx = float(xmax - xmin) / u0.size
    lambda_ = a * dt / dx
    u = u0.copy()
    for j in range(nt):
        # The Upwind method. The np.roll function helps us
        # account for the periodic boundary conditions.
        # U^{n+1}_i = U^n_i - (dt/dx)*(F^n_{i+.5} - F^n_{1-.5})
        # upwind: U^{n-1}_i = U^n_i - a(dt/dx) * (U^n_i - U^n_{i-1})
        u -= lambda_ * (u - np.roll(u, 1))
    # Get the x values for the plots.
    x = np.linspace(xmin, xmax, u0.size+1)[:-1]
    # Plot the computed solution.
    plt.plot(x, u, label='Upwind Method')
    # Find the exact solution and plot it.
    distance = a * t_final
    roll = int((distance - floor(distance)) * u0.size)
    plt.plot(x, np.roll(u0, roll), label='Exact solution')
    # Show the plot with the legend.
    plt.legend(loc='best')
    # plt.show()

# %%
def lax_wendroff(u0, a, xmin, xmax, t_final, nt):
    """ Solve the advection equation with periodic
    boundary conditions on the interval [xmin, xmax]
    using the upwind finite volume scheme.
    Use u0 as the initial conditions.
    a is the constant from the PDE.
    Use the size of u0 as the number of nodes in
    the spatial dimension.
    Let nt be the number of spaces in the time dimension
    (this is the same as the number of steps if you do
    not include the initial state).
    Plot and show the computed solution along
    with the exact solution. """
    dt = float(t_final) / nt
    # Since we are doing periodic boundary conditions,
    # we need to divide by u0.size instead of (u0.size - 1).
    dx = float(xmax - xmin) / u0.size
    lambda_ = dt / dx
    u = u0.copy()
    for j in range(nt):
        # The Upwind method. The np.roll function helps us
        # account for the periodic boundary conditions.
        # U^{n+1}_i = U^n_i - (dt/dx)*(F^n_{i+.5} - F^n_{1-.5})
        # upwind: U^{n-1}_i = U^n_i - a(dt/dx) * (U^n_i - U^n_{i-1})
        mn = (np.roll(u,-1) - u)/dx
        Fnminus = a*(np.roll(u,1) + np.roll(mn,1)*.5*(dx - a*dt))
        u -= lambda_ * (np.roll(Fnminus, -1) - Fnminus)
    # Get the x values for the plots.
    x = np.linspace(xmin, xmax, u0.size+1)[:-1]
    # Plot the computed solution.
    plt.plot(x, u, label='Upwind Method')
    # Find the exact solution and plot it.
    distance = a * t_final
    roll = int((distance - floor(distance)) * u0.size)
    plt.plot(x, np.roll(u0, roll), label='Exact solution')
    # Show the plot with the legend.
    plt.legend(loc='best')
    #plt.show()

# %%
def minmod_solve(u0, a, xmin, xmax, t_final, nt):
    """ Solve the advection equation with periodic
    boundary conditions on the interval [xmin, xmax]
    using the upwind finite volume scheme.
    Use u0 as the initial conditions.
    a is the constant from the PDE.
    Use the size of u0 as the number of nodes in
    the spatial dimension.
    Let nt be the number of spaces in the time dimension
    (this is the same as the number of steps if you do
    not include the initial state).
    Plot and show the computed solution along
    with the exact solution. """
    def minmod(a,b):
        if a*b > 0:
            if np.abs(a) < np.abs(b):
                return a
            else:
                return b
        else:
            return 0
    vect_minmod = np.vectorize(minmod)
    dt = float(t_final) / nt
    # Since we are doing periodic boundary conditions,
    # we need to divide by u0.size instead of (u0.size - 1).
    dx = float(xmax - xmin) / u0.size
    lambda_ = a * dt / dx
    u = u0.copy()
    mn = np.zeros_like(u0)
    for j in range(nt):
        # The Upwind method. The np.roll function helps us
        # account for the periodic boundary conditions.
        # U^{n+1}_i = U^n_i - (dt/dx)*(F^n_{i+.5} - F^n_{1-.5})
        # upwind: U^{n-1}_i = U^n_i - a(dt/dx) * (U^n_i - U^n_{i-1})
        arguments = (u - np.roll(u,1))/dx
        mn = vect_minmod(arguments, np.roll(arguments,-1))
        Fnminus = a*(np.roll(u,1) + np.roll(mn,1)*.5*(dx - a*dt))
        u -= lambda_ * (np.roll(Fnminus, -1) - Fnminus)
    # Get the x values for the plots.
    x = np.linspace(xmin, xmax, u0.size+1)[:-1]
    # Plot the computed solution.
    plt.plot(x, u, label='Upwind Method')
    # Find the exact solution and plot it.
    distance = a * t_final
    roll = int((distance - floor(distance)) * u0.size)
    plt.plot(x, np.roll(u0, roll), label='Exact solution')
    # Show the plot with the legend.
    plt.legend(loc='best')
    #plt.show()

# %%
# Define the initial conditions.
# Leave off the last point since we're using periodic
# boundary conditions.

# Run the simulation.
for nx in [30,60,120,240]:
    nt = nx * 3 // 2
    x = np.linspace(0., 1., nx+1)[:-1]
    u0 = np.exp(-(x - .3)**2 / .005)
    arr = (.6 < x)  &  (x < .7 )
    u0[arr] += 1.
    upwind(u0, 1.2, 0, 1, 1.2, nt)
    lax_wendroff(u0, 1.2, 0, 1, 1.2, nt)
    minmod_solve(u0, 1.2, 0, 1, 1.2, nt)
    plt.title("N={}".format(nx))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-13-5d134dc764ba> in <module>()
#      12     upwind(u0, 1.2, 0, 1, 1.2, nt)
#      13     lax_wendroff(u0, 1.2, 0, 1, 1.2, nt)
# ---> 14     minmod_solve(u0, 1.2, 0, 1, 1.2, nt)
#      15     plt.title("N={}".format(nx))
#      16     plt.show()
#
# <ipython-input-12-a829044ff3f1> in minmod_solve(u0, a, xmin, xmax, t_final, nt)
#      34         # upwind: U^{n-1}_i = U^n_i - a(dt/dx) * (U^n_i - U^n_{i-1})
#      35         arguments = (u - np.roll(u,1))/dx
# ---> 36         mn = vect_minmod(arguments, np.roll(arguments,-1))
#      37         Fnminus = a*(np.roll(u,1) + np.roll(mn,1)*.5*(dx - a*dt))
#      38         u -= lambda_ * (np.roll(Fnminus, -1) - Fnminus)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2574             vargs.extend([kwargs[_n] for _n in names])
#    2575
# -> 2576         return self._vectorize_call(func=func, args=vargs)
#    2577
#    2578     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2653
#    2654             if ufunc.nout == 1:
# -> 2655                 res = array(outputs, copy=False, subok=True, dtype=otypes[0])
#    2656             else:
#    2657                 res = tuple([array(x, copy=False, subok=True, dtype=t)
#
# OverflowError: Python int too large to convert to C long
